# %% [markdown]
# <a href="https://colab.research.google.com/github/ikoize/data-science-bootcamp9/blob/main/sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv("churn.csv")
df.head()
# Out:
#   churn  accountlength internationalplan voicemailplan  numbervmailmessages  \
# 0    No            128                no           yes                   25
# 1    No            107                no           yes                   26
# 2    No            137                no            no                    0
# 3    No             84               yes            no                    0
# 4    No             75               yes            no                    0
#
#    totaldayminutes  totaldaycalls  totaldaycharge  totaleveminutes  \
# 0            265.1            110           45.07            197.4
# 1            161.6            123           27.47            195.5
# 2            243.4            114           41.38            121.2
# 3            299.4             71           50.90             61.9
# 4            166.7            113           28.34            148.3
#
#    totalevecalls  totalevecharge  totalnightminutes  totalnightcalls  \
# ...

# %%
df['churn'] = df['churn'].map( {'Yes': 1,'No': 0} )
df.head()
# Out:
#    churn  accountlength internationalplan voicemailplan  numbervmailmessages  \
# 0      0            128                no           yes                   25
# 1      0            107                no           yes                   26
# 2      0            137                no            no                    0
# 3      0             84               yes            no                    0
# 4      0             75               yes            no                    0
#
#    totaldayminutes  totaldaycalls  totaldaycharge  totaleveminutes  \
# 0            265.1            110           45.07            197.4
# 1            161.6            123           27.47            195.5
# 2            243.4            114           41.38            121.2
# 3            299.4             71           50.90             61.9
# 4            166.7            113           28.34            148.3
#
#    totalevecalls  totalevecharge  totalnightminutes  totalnightcalls  \
# ...

# %%
y = df["churn"]
X = df[["totaldayminutes", "totaldaycalls", "totaldaycharge", "numbercustomerservicecalls"]]

# 1. split data
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.20, random_state=42)

## 2. train model

model = LogisticRegression()
model.fit(X_train, y_train)

## 3. score
train_error = model.score(X_train, y_train)

## 4. evaluate
test_error = model.score(X_test, y_test)


print("Train error is ",train_error)
print("Test error is " ,test_error)
# Out:
# Train error is  0.8575
# Test error is  0.854
